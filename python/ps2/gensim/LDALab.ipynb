# %% [markdown]
# # **Topic Modeling**

# %% [markdown]
# ## **Exercise 1.1: Processing the raw text**
#
# You will using the gensim python library to perform LDA on the Brown corpus
#
# We will start with the file `brown.txt`, which contains 500 documents from the Brown corpus, one document per line, with all punctuation removed.
#
# Read these documents into memory:

# %%
import nltk
from nltk.corpus import state_union
from nltk.corpus import stopwords
from nltk import word_tokenize
import string
docs=[]
files=state_union.fileids()
for f in files:
    docs.append(state_union.words(f))
stop = set(stopwords.words('english') + list(string.punctuation))
texts = [ [ w.lower() for w in d if w.lower() not in stop] for d in docs ]
# words=state_union.words()
# print(state_union.documents)
# print(len(words))
# texts = [ [w.lower()] for w in words ]
print(len(texts))
print(texts[0][0:100])
# texts = [i for i in word_tokenize([t.split() for t in texts]) if i.lower() not in stop]
from gensim.corpora import Dictionary
dictionary = Dictionary(texts)   #Index all words in the corpus
len(dictionary)                  #Number of word types
# Out:
# 65
# ['president', 'harry', 'truman', 'address', 'joint', 'session', 'congress', 'april', '16', '1945', 'mr', 'speaker', 'mr', 'president', 'members', 'congress', 'heavy', 'heart', 'stand', 'friends', 'colleagues', 'congress', 'united', 'states', 'yesterday', 'laid', 'rest', 'mortal', 'remains', 'beloved', 'president', 'franklin', 'delano', 'roosevelt', 'time', 'like', 'words', 'inadequate', 'eloquent', 'tribute', 'would', 'reverent', 'silence', 'yet', 'decisive', 'hour', 'world', 'events', 'moving', 'rapidly', 'silence', 'might', 'misunderstood', 'might', 'give', 'comfort', 'enemies', 'infinite', 'wisdom', 'almighty', 'god', 'seen', 'fit', 'take', 'us', 'great', 'man', 'loved', 'beloved', 'humanity', 'man', 'could', 'possibly', 'fill', 'tremendous', 'void', 'left', 'passing', 'noble', 'soul', 'words', 'ease', 'aching', 'hearts', 'untold', 'millions', 'every', 'race', 'creed', 'color', 'world', 'knows', 'lost', 'heroic', 'champion', 'justice', 'freedom', 'tragic', 'fate', 'thrust']
# 12669

# %%
allwords = [ dictionary[i] for i in dictionary ]
print(allwords[100:150])
# Out:
# ['country', 'courage', 'creating', 'creed', 'crew', 'criminals', 'crushed', 'dangerous', 'dare', 'dark', 'dawn', 'day', 'days', 'deadly', 'debt', 'decency', 'deciding', 'decisive', 'deeply', 'defeat', 'defeatism', 'defend', 'defenders', 'defense', 'delano', 'delayed', 'demand', 'democratic', 'departed', 'depend', 'depending', 'despair', 'destroy', 'determination', 'determined', 'devoid', 'devoted', 'dictates', 'died', 'differences', 'difficult', 'direction', 'discern', 'distant', 'divine', 'dmiral', 'dominate', 'domination', 'doomed', 'doubt']

# %%
dictionary.filter_extremes(no_below = 5, no_above = 0.5)
len(dictionary)
# Out:
# 3470

# %%
filteredwords = [ dictionary[i] for i in dictionary ]
print(filteredwords[100:150])
# Out:
# ['fundamental', 'general', 'generations', 'germany', 'gradually', 'grand', 'gratitude', 'grave', 'guidance', 'harbor', 'harmony', 'harry', 'hearts', 'heavy', 'heritage', 'horizon', 'hour', 'hours', 'humanity', 'humility', 'ideals', 'ill', 'impossible', 'inadequate', 'inevitable', 'insist', 'japan', 'jeopardize', 'judge', 'kept', 'king', 'knows', 'laid', 'lasting', 'leader', 'learn', 'learned', 'left', 'liberation', 'lived', 'looked', 'looking', 'lot', 'love', 'loved', 'loving', 'machinery', 'marshall', 'measure', 'memory']

# %% [markdown]
# Q1. Compare to the above. Which proportion of the vocabular was removed? What do you think was removed?

# %%
dictionary.token2id['fundamental']        #Indexes can change after filtering
# Out:
# 100

# %%
#dictionary.token2id['flake']          #Some words have disappeared after filtering

# %%
#dictionary.token2id['the']            #Some words have disappeared after filtering

# %% [markdown]
# Q2. Check to see if you are right about the some of words that were removed.

# %%
set(allwords) - set(filteredwords)
# Out:
# {'trip',
#  'copays',
#  'reacts',
#  'olympic',
#  'salary',
#  'swore',
#  'prohibition',
#  'jakarta',
#  'columbine',
#  'analysts',
#  'relied',
#  'misguided',
#  'fascism',
#  'caucus',
#  'notion',
#  'dishearten',
#  'openly',
#  'success',
#  'commended',
#  'tighter',
#  'rolled',
#  'strength',
#  'jealously',
#  '12th',
#  'music',
#  'laos',
#  'rover',
#  'split',
#  'jailed',
#  'madrid',
#  'contagious',
#  'coalitions',
#  'halted',
#  'permission',
#  'congressmanąxalong',
#  'reconstruct',
#  'tight',
#  'aggressively',
#  'convert',
#  'improve',
#  'europe',
#  'roquejeoffre',
#  'descend',
#  'basic',
#  'thomases',
#  'steuben',
#  'inches',
#  'propose',
#  'animated',
#  'disclosure',
#  'clark',
#  'policies',
#  'speaks',
#  'regulating',
#  'providence',
#  'provide',
#  'fo',
#  'shall',
#  'honorably',
#  'tab',
#  'secretaries',
#  'dirtier',
#  'privations',
#  'attainable',
#  'atheistic',
#  'reiterate',
#  'outstandingly',
#  'deplorable',
#  'impressed',
#  'independence',
#  '755',
#  'vii',
#  'protector',
#  'repayment',
#  'allegations',
#  'connecting',
#  '1990',
#  'mortality',
#  'unsatisfactory',
#  'suited',
#  'unstinted',
#  'motor',
#  'renounced',
#  'reasonably',
#  'flower',
#  'farmlands',
#  'respective',
#  'worrying',
#  'moakley',
#  'fees',
#  'lets',
#  'abstinence',
#  'ethic',
#  'deepen',
#  'kosovo',
#  'purposeąxa',
#  'intermittently',
#  'jason',
#  'raf',
#  'teaches',
#  'tangle',
#  'gram',
#  'crowded',
#  'nevada',
#  '102',
#  'fliers',
#  'turn',
#  'associate',
#  'fingerprints',
#  'countrymen',
#  'towers',
#  'floor',
#  'opens',
#  'belly',
#  '156',
#  'entities',
#  'cream',
#  'supervised',
#  'stripes',
#  'fountainhead',
#  'pushers',
#  'brilliant',
#  'minors',
#  'cl',
#  'spider',
#  'depths',
#  'coaches',
#  'rape',
#  'errors',
#  'scientist',
#  'tap',
#  'signify',
#  'montana',
#  'pall',
#  'aggregate',
#  'prep',
#  'growthąxgrowth',
#  'present',
#  'tejeda',
#  'highest',
#  'collected',
#  'override',
#  'subtle',
#  'shudder',
#  'shipyard',
#  'tem',
#  'often',
#  'abreast',
#  'virginia',
#  'homebuyers',
#  'restructuring',
#  'blockbusters',
#  'happier',
#  'vacation',
#  'logic',
#  'width',
#  'eighty',
#  'infamy',
#  'stalemate',
#  'deployment',
#  'stand',
#  'refer',
#  'symptom',
#  'backing',
#  'unreserved',
#  'spotting',
#  'fogarty',
#  'whirlwind',
#  'spurred',
#  'spendthrift',
#  'aboard',
#  'hamburg',
#  'cybernetics',
#  'middle',
#  'speculative',
#  'confuse',
#  'adaptation',
#  'mx',
#  'reminding',
#  'voluntarily',
#  'unhesitating',
#  'graves',
#  'recomputed',
#  'socialization',
#  'packages',
#  'hostage',
#  'champions',
#  'philosophical',
#  'promoted',
#  'vi',
#  'clerk',
#  'outweigh',
#  'displayed',
#  'starkly',
#  'system',
#  'tortured',
#  'enmities',
#  'tubman',
#  'depict',
#  'truculent',
#  'adversely',
#  'flourished',
#  'humbly',
#  'suspended',
#  'judeo',
#  'birthdays',
#  'relay',
#  'lifeblood',
#  'silver',
#  'procedural',
#  'reveals',
#  'leaps',
#  'retardation',
#  'indefensible',
#  'united',
#  'glass',
#  'plentiful',
#  'cohesion',
#  'outstrips',
#  'pound',
#  'disregard',
#  'gdansk',
#  'administering',
#  'warming',
#  'fury',
#  'cheaply',
#  'inadequacies',
#  'endangers',
#  'shelf',
#  'careers',
#  'restlessness',
#  'rose',
#  'dozens',
#  'eternal',
#  'abridges',
#  'energetic',
#  'winner',
#  'expertise',
#  'advocating',
#  'stabilization',
#  'genes',
#  'habeas',
#  'theater',
#  'burdensome',
#  'chesapeake',
#  'instructing',
#  'discern',
#  'nuns',
#  'representation',
#  'recite',
#  'suspected',
#  'hills',
#  'bill',
#  'almost',
#  'calculations',
#  'disclosures',
#  'savagery',
#  'searching',
#  'fritter',
#  'nearby',
#  'continuously',
#  'handle',
#  'moderation',
#  'parade',
#  'antimissile',
#  'ottawa',
#  'establishes',
#  'billion',
#  'fortress',
#  'afflictions',
#  'pieces',
#  'harmonizing',
#  'stalkers',
#  'overblown',
#  'challenge',
#  'driven',
#  'farm',
#  '1959',
#  'compressed',
#  'coastlines',
#  'sentence',
#  'semi',
#  'excellency',
#  'environment',
#  'explosives',
#  'aptitude',
#  '93d',
#  'readjusting',
#  'egg',
#  'invests',
#  'mansfield',
#  'kinslow',
#  'scored',
#  'advocates',
#  '1929',
#  'becomeąxas',
#  'democratically',
#  'spann',
#  'justifying',
#  'capps',
#  'hattiesburg',
#  'astronauts',
#  'clothe',
#  'initiate',
#  'carpenters',
#  'justifiable',
#  'missed',
#  'ministers',
#  'clem',
#  'comprise',
#  'merchants',
#  'amid',
#  'edinboro',
#  'bentsen',
#  'deficiency',
#  'bluntly',
#  'heralding',
#  'disparaged',
#  'posts',
#  'repaired',
#  'commented',
#  'assassinated',
#  'facilitates',
#  'overworked',
#  'ward',
#  'enemyąśs',
#  'translated',
#  'neutral',
#  'document',
#  'creased',
#  'criers',
#  'parklands',
#  'erase',
#  'encumber',
#  'flared',
#  'glassboro',
#  'honors',
#  'shortest',
#  '229',
#  'farming',
#  'incompetence',
#  'preach',
#  'steep',
#  'obey',
#  'taiwan',
#  'alabama',
#  'undivided',
#  'molecular',
#  'summons',
#  'gettysburg',
#  'makes',
#  'stiff',
#  'pronouncements',
#  'sixfold',
#  'documents',
#  'barren',
#  '14th',
#  'territorial',
#  'cut',
#  'epitomized',
#  'varies',
#  'letterman',
#  '943',
#  'criterion',
#  'trujillo',
#  'polluted',
#  'janes',
#  'suzann',
#  'business',
#  'appropriated',
#  'fashioned',
#  'ignoring',
#  'shelby',
#  'everlasting',
#  'contradiction',
#  'boldest',
#  'stiffen',
#  'blindfolded',
#  'alertness',
#  'crying',
#  'enters',
#  'build',
#  'backed',
#  'forsaking',
#  'brownfields',
#  'slipping',
#  'burned',
#  'commentary',
#  'dismiss',
#  'opec',
#  'jersey',
#  'sworn',
#  '77',
#  'aspired',
#  'narcotic',
#  'agent',
#  'surgery',
#  'task',
#  'belligerence',
#  'unconditional',
#  'residential',
#  'bombed',
#  'backward',
#  'needed',
#  'gulfs',
#  'culminated',
#  'bulgaria',
#  'slots',
#  'dripping',
#  'associations',
#  'statue',
#  'frank',
#  'oversee',
#  'denies',
#  'mubarak',
#  'defender',
#  'futureąxa',
#  'confounded',
#  'unhindered',
#  'angular',
#  'outset',
#  'fema',
#  'deportation',
#  'draws',
#  'sponsor',
#  'privately',
#  'discretion',
#  'toil',
#  'chorus',
#  'medicines',
#  'mills',
#  'wears',
#  'wrested',
#  'vestibule',
#  'golden',
#  'challenger',
#  'overhauled',
#  'clearing',
#  'geared',
#  'surrendering',
#  'ritual',
#  'empires',
#  'functionally',
#  'taxes',
#  'sheer',
#  'formulate',
#  'whooping',
#  'signaling',
#  'lessening',
#  'generates',
#  'agonies',
#  'certainties',
#  'madman',
#  'timing',
#  'stipulates',
#  'passenger',
#  'concepts',
#  'inauguration',
#  'steadfastness',
#  'regress',
#  'surcharge',
#  'hurting',
#  'upąxand',
#  'astronomers',
#  'activist',
#  'reaffirms',
#  '117',
#  'afforded',
#  'barry',
#  'adnan',
#  'lock',
#  'investigated',
#  'nondiscrimination',
#  'ruckelshaus',
#  'usually',
#  'warms',
#  'lawsuit',
#  'slightly',
#  'join',
#  'classification',
#  'intricate',
#  'timetables',
#  'versatile',
#  'resulted',
#  'substituting',
#  'pine',
#  'relent',
#  '1970s',
#  '571',
#  'worthwhile',
#  'statutes',
#  'heed',
#  'usama',
#  'fifths',
#  'revive',
#  'additionally',
#  'sizable',
#  'enforcing',
#  'undesirable',
#  'mismanaged',
#  'bleeding',
#  'penalize',
#  'family',
#  'breathing',
#  'lindbergh',
#  'leveling',
#  'exporter',
#  'formalized',
#  'crew',
#  'leadersąś',
#  'bond',
#  'mostly',
#  'preserve',
#  'indomitable',
#  'eastward',
#  '000ąxhas',
#  'jihad',
#  'another',
#  'greeting',
#  'clause',
#  'obligated',
#  'venom',
#  'purposesąxfor',
#  'nobly',
#  'uphill',
#  'prohibitive',
#  'experimentation',
#  'soldier',
#  'tierra',
#  'prosecutors',
#  'tort',
#  'cooperation',
#  'linger',
#  'fever',
#  'importation',
#  'religions',
#  'kristen',
#  'among',
#  'uzbekistan',
#  'tempting',
#  'martin',
#  'ugly',
#  'voiced',
#  'torch',
#  'bible',
#  'chris',
#  'timeless',
#  'assistance',
#  'brawn',
#  'ashley',
#  'sexual',
#  'assessment',
#  'handcuffs',
#  'opa',
#  'intensity',
#  'dissolution',
#  'envelope',
#  'incidentally',
#  'letąśs',
#  'clergy',
#  '94th',
#  'mujahadeen',
#  'thinly',
#  'varying',
#  'stark',
#  'gleam',
#  'reinvigorate',
#  'fitzgerald',
#  'living',
#  '8th',
#  'theme',
#  'doorkeeper',
#  'lifesaving',
#  'tightly',
#  'faint',
#  '675',
#  'designate',
#  'multi',
#  'historical',
#  'phrase',
#  'resentment',
#  'locally',
#  'finite',
#  'nelle',
#  'slump',
#  'rider',
#  'deterring',
#  'pre',
#  'ask',
#  'catalogued',
#  'birthplace',
#  'process',
#  'agonizing',
#  'ascertain',
#  'lighting',
#  'protocol',
#  'doubtful',
#  'tuzla',
#  'gravest',
#  'snipers',
#  'accurate',
#  'bars',
#  'sustaining',
#  'energizing',
#  'abating',
#  'cd',
#  'growth',
#  'stretching',
#  'judd',
#  'influx',
#  'joyous',
#  'device',
#  'hassan',
#  'brainpower',
#  'approving',
#  'reminiscent',
#  'flex',
#  'unalienable',
#  'digress',
#  'issuance',
#  'preponderance',
#  'cardinal',
#  'treatments',
#  'tuned',
#  'proliferated',
#  'prevailing',
#  'overgrown',
#  'warhead',
#  '6th',
#  'doubles',
#  'masters',
#  'irresponsibility',
#  'hijack',
#  'inextricably',
#  'gallantly',
#  'pushes',
#  'mysterious',
#  'candles',
#  'found',
#  'ranges',
#  'cochair',
#  '1996',
#  'swap',
#  'freedom',
#  'german',
#  'informs',
#  'isolate',
#  'cuellar',
#  'billiere',
#  'vices',
#  'validate',
#  'assumes',
#  'brightened',
#  'languages',
#  'shays',
#  'generation',
#  'referendum',
#  'saves',
#  'delays',
#  'volatile',
#  'unify',
#  'clerks',
#  'end',
#  'telephone',
#  'machi',
#  'seige',
#  'libertiesąxwhat',
#  '676',
#  'overtime',
#  'supplying',
#  'hydroelectric',
#  'absorption',
#  'cancellation',
#  'formations',
#  'hindrance',
#  'seventy',
#  'incoherent',
#  'gravity',
#  'spontaneously',
#  'users',
#  '20s',
#  'afterwards',
#  'metals',
#  'disengagement',
#  'overregulation',
#  'nice',
#  'static',
#  'appraisers',
#  'soothe',
#  'associates',
#  'securely',
#  'render',
#  'papers',
#  'escapes',
#  'obligational',
#  'deafened',
#  'widows',
#  'packard',
#  'pen',
#  'hoover',
#  'cleansing',
#  'manchuria',
#  'life',
#  'insistent',
#  'presidentąśs',
#  'unto',
#  'fiercer',
#  'overhead',
#  'freest',
#  'ability',
#  'script',
#  'presided',
#  'pete',
#  'excesses',
#  'reporter',
#  'relatives',
#  'supporters',
#  'two',
#  'peering',
#  'wedlock',
#  'absurd',
#  'biblical',
#  'tiring',
#  'seizes',
#  '1990ąśsąxat',
#  'conducted',
#  'phones',
#  'reviving',
#  'surrounded',
#  'jaish',
#  'interferes',
#  'works',
#  'folly',
#  'pornography',
#  'instructed',
#  'em',
#  'translation',
#  'elemental',
#  'fuzzy',
#  '1973',
#  'inventory',
#  'opic',
#  'gaza',
#  'exceeds',
#  'electoral',
#  '154',
#  'democrat',
#  'engulfing',
#  'incur',
#  'soundest',
#  'markedly',
#  'perpetual',
#  'airborne',
#  'sword',
#  'murderers',
#  '130',
#  'mayor',
#  '1984',
#  'right',
#  'tapped',
#  'horrified',
#  'polls',
#  'glorification',
#  'meland',
#  'midpoint',
#  'journalists',
#  'tons',
#  'el',
#  'reconsideration',
#  'photo',
#  'observation',
#  'comparison',
#  'countenance',
#  'localitiesąxa',
#  'inglorious',
#  'unselfishly',
#  'fanfare',
#  'humane',
#  'embargo',
#  'tackling',
#  'distinct',
#  'unkind',
#  'surge',
#  'admiral',
#  'contemplate',
#  'umons',
#  'unfairness',
#  'widow',
#  'stems',
#  'indebtedness',
#  'sensationalism',
#  'age',
#  'nazism',
#  'myth',
#  'ratify',
#  'undercuts',
#  'dramatizes',
#  'prophecies',
#  'liberty',
#  'crucible',
#  'revitalization',
#  'pursuits',
#  'explode',
#  'accumulation',
#  'originally',
#  'auto',
#  'irresponsible',
#  'eulogized',
#  'explanations',
#  'dc',
#  'wellbeing',
#  'lee',
#  'newport',
#  'partnership',
#  'executed',
#  'colonialism',
#  'bicker',
#  'acceleration',
#  'swayed',
#  'latter',
#  'mischief',
#  'clarity',
#  'looms',
#  'inequitable',
#  'assignment',
#  'rivals',
#  'confirms',
#  'surgeon',
#  'opportunistic',
#  'consular',
#  'leveled',
#  'paragraph',
#  'years',
#  'yearąśs',
#  'clipper',
#  'requires',
#  'increasing',
#  'hollings',
#  'shuffling',
#  'subsides',
#  'floodlighted',
#  'flowering',
#  'sixty',
#  'percentagewise',
#  'shameful',
#  'soak',
#  'rugged',
#  'enjoys',
#  'careless',
#  'arouse',
#  'restaurants',
#  'attitudes',
#  'firearms',
#  'suitable',
#  'achieve',
#  'electronically',
#  'blunted',
#  'indianapolis',
#  'marriages',
#  'inappropriate',
#  '83',
#  'thwarted',
#  'real',
#  'electrification',
#  'coretta',
#  'sima',
#  'enforced',
#  'control',
#  'apprenticeship',
#  'wealthiest',
#  'window',
#  '825',
#  'exerts',
#  'execute',
#  'miraculous',
#  'currently',
#  'vastly',
#  'drilling',
#  'taxeaters',
#  'games',
#  'traders',
#  'subtract',
#  'appliances',
#  'revitalized',
#  '1942',
#  'writing',
#  'cast',
#  'communize',
#  'financially',
#  'insuperable',
#  '266',
#  'beds',
#  'pollute',
#  'benevolence',
#  'unlawfully',
#  'registrar',
#  'intractable',
#  'rescissions',
#  'gases',
#  'scars',
#  'orleans',
#  'medic',
#  'barrels',
#  'manila',
#  'understandably',
#  'pretenses',
#  'title',
#  'knowingly',
#  'desperate',
#  'cynics',
#  'illicit',
#  'faltering',
#  'immunity',
#  'raged',
#  'president',
#  'picketing',
#  'carry',
#  'conquering',
#  'coli',
#  'fda',
#  'sweat',
#  'sealed',
#  'assembling',
#  'brandeis',
#  'expedient',
#  'indistinct',
#  'publicly',
#  'injuries',
#  'planting',
#  'measurement',
#  'motion',
#  'player',
#  'prospering',
#  'millionaire',
#  'order',
#  'fault',
#  'cartel',
#  'undeniable',
#  'kosygin',
#  'unbroken',
#  'healthier',
#  'version',
#  'wracked',
#  'amassing',
#  'marginalized',
#  'incomeąxthat',
#  'proclaims',
#  'conqueror',
#  'lebanese',
#  'conveniences',
#  'schuller',
#  'tip',
#  'hydrogen',
#  'yitzhak',
#  'riyadh',
#  'examined',
#  'logical',
#  'strengthens',
#  'lateral',
#  'depreciating',
#  'unessential',
#  'mechanisms',
#  'social',
#  'coasts',
#  'bureau',
#  'communicating',
#  'minuteman',
#  'redeems',
#  'trigger',
#  'endangering',
#  'germans',
#  'relocation',
#  'physically',
#  'repaint',
#  'combines',
#  'unwarranted',
#  'formal',
#  'curbed',
#  'finalize',
#  'underclass',
#  'harness',
#  'mainly',
#  'indians',
#  'capture',
#  'hasty',
#  'flexibly',
#  'requisite',
#  'depending',
#  'uncertain',
#  'fled',
#  'put',
#  'racketeers',
#  'samar',
#  'inflicted',
#  'lied',
#  'incidence',
#  'bore',
#  'stopgaps',
#  'completion',
#  'anderson',
#  ...}

# %% [markdown]
# Q3. How would you only remove words that occur frequenly across the corpus? Why would you (not) want to do this? (Tip: Review cell 52.)

# %% [markdown]
# You can save a dictionary with `.save(filename)`

# %%
dictionary.save('LDALab.bow.dict')

# %% [markdown]
# ## **Exercise 1.2c: Processing and serializing the corpus**
#
# The function `.doc2bow()` will convert a document to a list of tuples of the unique word indexes in the document and how many times they appear. i.e. [ (word_index, count), (word_index, count), ...]
#
# Do this for the entire collection of texts:

# %%
bow_corpus = [dictionary.doc2bow(t) for t in texts ]
# print (bow_corpus[0:100])
print(len(bow_corpus))
# Out:
# 65

# %% [markdown]
# This can also be done on unseen documents (unseen words will be ignored):

# %%
dictionary.doc2bow('This document defeat nation PRESIDENT has unseen words like Trafalmadorian'.split())
# Out:
# [(51, 1)]

# %%
dictionary[52], dictionary[54], dictionary[78]
# Out:
# ('defenders', 'depend', 'enlightened')

# %% [markdown]
# Q4. Which words are not indexed? Why?

# %% [markdown]
# Serializing such a processed corpus allows us to store it and read it back in another time

# %%
from gensim.corpora import MmCorpus 
MmCorpus.serialize('LDALab.bow.mm', bow_corpus)

# %% [markdown]
# ## **Exercise 1.3: Bag-of-words to LDA**
#
# Let’s train a **30 topic LDA model** on the first 80% of the documents and evaluate it on the remaining 20%.
#
# Split the bag-of-words corpus into 80% for training and 20% for testing.

# %%
size = int(len(bow_corpus) * 4 / 5)
training = bow_corpus[:size]
testing = bow_corpus[size:]

# %% [markdown]
# Now we can train an `LdaModel` object with the following parameters:
#   * the processed corpus of interest
#   * `id2word` = the dictionary so that we can print the words instead of the indexes
#   * `num_topics` = the number of topics (an important parameter to experiment with)
#   * `passes` = the number of iterations for parameter-learning (we only have 500 documents; larger corpora may involve different number of passes for reasonable results)
#
# **This might take up to 2 minutes or so to run. Please be patient. You can look ahead at instructions below while waiting.**

# %%
from gensim.models import LdaModel
lda30 = LdaModel(training, id2word=dictionary, num_topics=10, passes=30)

# %% [markdown]
# Q5. How do you know if you have chosen a good number of topics?

# %% [markdown]
# ## **Exercise 1.4a: Evaluating LDA - interpreting**
#
# The `LdaModel` object has a built-in function to print topics/return raw data `.show_topics()`. Its output is hard to read, so a nicer function `pretty_topics()` has been provided for you.
#
# Import the `pretty_topics()` function from `demo` (in the lab directory). It will print the top 10 words and their probabilities per topic. Use this to examine the topics. (Remember: The word distribution is over the full vocabulary, not just frequent words. For a given topic, it sums to 1.)

# %%
from demo import pretty_topics
pretty_topics(lda30)
# Out:
# Topic 1:
# 	0.00766 messages
# 	0.00550 general
# 	0.00550 ideals
# 	0.00550 wars
# 	0.00550 victory
# 	0.00550 dominate
# 	0.00550 heavy
# 	0.00442 affairs
# 	0.00442 mutual
# 	0.00442 ą
# Topic 2:
# 	0.00608 vietnam
# 	0.00525 communist
# 	0.00342 alliance
# 	0.00311 try
# 	0.00297 strategic
# 	0.00278 recommendations
# 	0.00272 republic
# 	0.00272 branch
# 	0.00265 skills
# 	0.00263 recommend
# Topic 3:
# 	0.00690 side
# 	0.00577 1964
# 	0.00464 decent
# 	0.00464 lack
# 	0.00351 hospitals
# 	0.00351 merely
# 	0.00351 short
# 	0.00351 transit
# 	0.00351 color
# 	0.00351 john
# Topic 4:
# 	0.02621 vietnam
# 	0.01148 south
# 	0.00849 recommend
# 	0.00754 principle
# 	0.00642 north
# 	0.00622 conflict
# 	0.00605 .]
# 	0.00425 trying
# 	0.00413 8
# 	0.00404 stay
# Topic 5:
# 	0.00291 tell
# 	0.00285 something
# 	0.00280 speak
# 	0.00247 cuts
# 	0.00239 recovery
# 	0.00236 pass
# 	0.00232 space
# 	0.00226 dream
# 	0.00225 parents
# 	0.00223 ensure
# Topic 6:
# 	0.01890 gulf
# 	0.01416 iraq
# 	0.01189 victory
# 	0.01014 saddam
# 	0.00983 desert
# 	0.00899 storm
# 	0.00838 conflict
# 	0.00821 region
# 	0.00713 persian
# 	0.00635 general
# Topic 7:
# 	0.00742 foundation
# 	0.00505 missile
# 	0.00489 missiles
# 	0.00418 mutual
# 	0.00406 scientific
# 	0.00401 ballistic
# 	0.00380 science
# 	0.00377 deterrent
# 	0.00372 ą
# 	0.00339 potential
# Topic 8:
# 	0.00427 space
# 	0.00401 peoples
# 	0.00372 capacity
# 	0.00285 field
# 	0.00283 ideals
# 	0.00263 communist
# 	0.00254 affairs
# 	0.00253 concern
# 	0.00249 european
# 	0.00247 demands
# Topic 9:
# 	0.00793 oil
# 	0.00663 recommend
# 	0.00442 actions
# 	0.00421 highway
# 	0.00390 conservation
# 	0.00379 request
# 	0.00308 consumer
# 	0.00298 expenditures
# 	0.00297 adequate
# 	0.00292 recommendations
# Topic 10:
# 	0.01260 expenditures
# 	0.00845 1947
# 	0.00581 management
# 	0.00570 1946
# 	0.00540 veterans
# 	0.00536 recommended
# 	0.00534 estimated
# 	0.00519 debt
# 	0.00507 general
# 	0.00487 adequate

# %% [markdown]
# To see more topics than 2, update the variable num_topics in `pretty_topics()` in demo.py by going to the file,  clicking it to open a text editor, revising the variable value, and then saving the file. Then, restart this notebook with `Kernel` > `Restart & Run All`. Be patient and wait a bit.
#
# Topics will not be exactly the same because of randomness in the model.
#
# Q6. How difficult/straightforward is it to interpret the topics? Do some make more sense than others?
#
# Q7. How would you name the topics that do make sense?

# %% [markdown]
# ## **Exercise 1.4b: Evaluating LDA - perplexity**
#
# Now we will compute the **perplexity** of the model on the test data.
#
# Remember that LDA is a **generative model**. After training the parameters of the model, let’s test
# the likelihood of this model randomly generating the held-out test set.
#
# The `.log_perplexity()` function of the `LdaModel` will give the log perplexity.

# %%
lg_perp = lda30.log_perplexity(testing)
lg_perp
# Out:
# -9.964095023170715

# %%
perp = 2 ** -(lg_perp) # Calculate perplexity 
perp
# Out:
# 998.8297784039629

# %% [markdown]
# Your results may not be exactly the same, but should be reasonably close.
#
# For comparison, using a version of this trained model on an external dataset (not given in lab) yielded a perplexity of 42,224 -- much much worse than on our test set from the same corpus.

# %% [markdown]
# Q8. For LDA, do you think perplexity is linked to model interpretability?
